# %% [markdown]
# # ¡Bienvenidos a la tercera sesión del Mastery Data Science!
#
# Ya aprendimos lo necesario y es hora de practicar lo aprendido.
#
# ## Estructura del día
#
# ### Primera sesión: 10:00 - 12:00
#
# Trabajemos en la sección de ejercicios. No tienen que hacer todos en este tiempo, pero les servirá para resolver dudas que posiblemente les ayuden en la siguiente sección. El documento a trabajar esta en la otra carpeta.
#
# ### Segunda parte: 12:00 - 15:40 (incluyendo la hora de la comida)
#
# Se les presenta un ejercicio de aplicación donde sólo apliquen los comandos básico de Python.
#
# ### Cierre
#
# - Contesta la encuesta en la siguiente liga, nos ayudará a mejorar mucho como el curso y como equipo: http://bit.ly/0919datascience
#
# - ¿Comentarios sobre la primer semana?
#
# **Nota:** ¡recuerden cargar su ambiente!

# %% [markdown]
# # Proyecto - La Divina comedia
# ## 1. Antes de empezar
# - Planea tu código: Antes de escribir código debemos sentarnos, pensar que hacer, hacer un plan (se le llama pseudocódigo) y luego ya tienes permiso de escribir código.
# - ¿No se que hacer? Google it! Seguramente en internet tiene seguramente las respuesta
# - Divide y conquistaras: trabaja segmentando el código en celdas y revisa que cada acción importante se realice la manera correcta
# - Si crees que usaras recurrentemente la sección de código que hace algo, sería conveniente hacer una función ¿no?
#
#
# ## 2. Descripción
#
# Para este ejemplo usaremos del texto en ingles de *La Divina Comedia* escrita por Dante Alighieri y fue descargado desde *Project Gutenberg* con nombre **8800.txt**. Existen muchas maneras de realizar este ejercicio, no te preocupes por lo que hacen los demas. Realiza mediante comandos, no uses funciones hasta que se te pida.
#
#
# **Preguntas**
#
#
# - ¿Cuántas palabras existen en los primeros 5,000 caracteres?
# - ¿Cuántas palabras únicas existen en el mismo rango?
# - ¿Importan las mayúsculas y minúsculas?
# - ¿Cuántas veces aparece la palabra **the** en ese rango?
# - ¿Puedo saber cuantas veces existe una palabra en el texto cargado?
# - Crea un diccionario donde asignes el número de apariciones a la palabra existente
# - ¿Qué pasa con los signos de puntuación, es decir, 'me', 'me;', 'me.', 'me?' y 'me,' son iguales?
#     - ¿Cuáles existen? ¿Estan todos en la misma posición?
# - Elimina los signos de puntuación y realiza el mismo ejercicio
#
#
# Ahora crea funciones para realizar las mismas preguntas y usalas para analizar el texto completo (todo un reto).
#
# ## 3. Comparación de resultados y métodos
#
# ¡Comparemos la lógica de sus códigos! Nadie piensa igual y la diversidad nos permite encontrar mejores soluciones mediante el diálogo.

# %% [markdown]
# ## 4. ¿Quieren más? - Recursos de apoyo
#
# - Platarformas: EDX, Coursera, Udemy, DataCamp
# - Empresas: IBM, Microsoft
# - Millones de páginas web
# - Cientos de libros (como los que ya les pasamos)

# %%
import re

a_str = 'the test; text test. Hello'
re.split(r" |(?<![0-9])[.,;](?![0-9])", a_str)

def read_file(fileName, num_carac):
    my_file = open(fileName, "r")
    my_result = ''
    found = False
    for line in my_file:
        found = 'CANTO I' in line or found
        if (found):
            my_result += line
    length_text = len(my_result)
    num_carac_fix = num_carac
    if (num_carac_fix > length_text):
        num_carac_fix = length_text
    return (my_result[:num_carac_fix])
text_file = read_file('8800.txt',5000)

#print(text_file)

word_list = re.sub("[^\w]", " ",  text_file).lower().split()
print(f'number of words:{len(word_list)}')
set_words = set(word_list)
number_unique_word = len(set_words)
print(f'number of unique words:{number_unique_word}')

def count_words(word,word_list):
    result = 0
    for aword in word_list:
        if aword == word:
            result=result+1
    return result

count_the = count_words('the', word_list)
print(f'number of "the" words is {count_the}')

def build_dictonary(word_list):
    set_words = set(word_list)
    key_words = list(set_words)
    result_dict = {}
    for akey_word in key_words:
        result_dict[akey_word] = count_words(akey_word,word_list)
    return result_dict

words_dict = build_dictonary(word_list)
#print(words_dict)

a_list = [(k, v) for k, v in words_dict.items()]
print(a_list)
def custom_sort(item):
     return item[1]
a_list.sort(key=custom_sort)
a_list
# Out:
# number of words:959
# number of unique words:465
# number of "the" words is 44
# [('glaucus', 1), ('allowed', 1), ('memory', 1), ('false', 1), ('o', 2), ('boiling', 1), ('at', 2), ('words', 2), ('en', 1), ('a', 10), ('him', 2), ('eternal', 2), ('mortals', 1), ('ran', 1), ('sea', 1), ('much', 3), ('source', 1), ('lighter', 1), ('being', 1), ('bosom', 1), ('here', 2), ('upon', 3), ('before', 1), ('fast', 1), ('bick', 1), ('frenzied', 1), ('form', 3), ('sacred', 1), ('enterprise', 1), ('calm', 1), ('pierian', 1), ('sheds', 1), ('marsyas', 1), ('appear', 1), ('higher', 1), ('gods', 1), ('hath', 4), ('accompanied', 1), ('said', 1), ('knits', 1), ('less', 2), ('own', 2), ('stood', 1), ('guide', 1), ('and', 24), ('suffic', 1), ('up', 1), ('forth', 2), ('child', 1), ('behold', 1), ('more', 4), ('diver', 1), ('ne', 2), ('steep', 1), ('apollo', 1), ('tree', 1), ('voice', 1), ('though', 1), ('st', 3), ('passage', 1), ('line', 1), ('bear', 1), ('course', 2), ('absorb', 1), ('bard', 1), ('dwelling', 1), ('into', 2), ('began', 2), ('if', 3), ('newly', 1), ('dost', 1), ('threefold', 1), ('universe', 2), ('sky', 1), ('who', 4), ('vessel', 1), ('among', 2), ('store', 2), ('resemble', 1), ('transhuman', 1), ('iron', 1), ('herb', 1), ('than', 1), ('doubt', 2), ('mov', 2), ('divine', 1), ('piteous', 1), ('realm', 2), ('ris', 1), ('others', 1), ('their', 3), ('now', 3), ('entangled', 1), ('second', 1), ('joy', 1), ('didst', 2), ('morning', 1), ('never', 1), ('desire', 2), ('ken', 2), ('may', 3), ('crown', 1), ('lake', 1), ('wheel', 1), ('mighty', 1), ('brief', 1), ('reflected', 1), ('better', 2), ('do', 1), ('four', 1), ('delphic', 1), ('er', 3), ('glory', 1), ('bodies', 1), ('limbs', 1), ('risen', 1), ('drawn', 1), ('only', 2), ('mother', 1), ('tasted', 1), ('when', 4), ('beheld', 1), ('seest', 1), ('bow', 1), ('imagination', 1), ('bedeck', 1), ('impart', 1), ('sparks', 1), ('look', 1), ('sigh', 1), ('whence', 2), ('world', 1), ('spark', 1), ('off', 1), ('rain', 1), ('n', 5), ('enter', 1), ('shame', 1), ('what', 1), ('unmov', 1), ('aspect', 1), ('some', 2), ('thy', 5), ('open', 1), ('ever', 1), ('inflam', 1), ('must', 1), ('might', 1), ('prompts', 1), ('of', 25), ('grace', 2), ('return', 2), ('his', 6), ('approaching', 2), ('earth', 2), ('wheels', 1), ('partakes', 1), ('this', 7), ('ning', 1), ('saw', 2), ('havens', 1), ('gaze', 1), ('rises', 1), ('eyes', 3), ('day', 2), ('flame', 2), ('heav', 3), ('but', 4), ('natures', 1), ('as', 12), ('god', 2), ('place', 2), ('seldom', 1), ('gathers', 1), ('made', 4), ('straight', 1), ('act', 1), ('mind', 1), ('trac', 1), ('beam', 1), ('dull', 1), ('caesar', 1), ('near', 1), ('other', 1), ('i', 14), ('theme', 1), ('example', 1), ('circles', 1), ('by', 7), ('pierces', 1), ('thyself', 1), ('have', 2), ('temper', 2), ('cannot', 1), ('leaves', 1), ('myself', 2), ('depth', 1), ('benign', 1), ('gain', 1), ('r', 1), ('clearly', 1), ('first', 2), ('create', 1), ('worth', 2), ('blaze', 1), ('constellation', 1), ('spirit', 1), ('serve', 1), ('joins', 1), ('beyond', 1), ('keener', 1), ('pray', 1), ('satisfied', 1), ('therefore', 1), ('its', 5), ('admire', 1), ('seen', 1), ('henceforth', 1), ('rest', 1), ('elsewhere', 1), ('there', 4), ('utt', 1), ('new', 2), ('me', 12), ('blackness', 1), ('seem', 1), ('fit', 1), ('claims', 1), ('whose', 1), ('is', 8), ('mortal', 2), ('light', 4), ('sphere', 1), ('through', 4), ('intellect', 2), ('sun', 4), ('are', 3), ('high', 1), ('perchance', 1), ('in', 11), ('on', 6), ('foot', 1), ('honour', 1), ('themselves', 1), ('small', 1), ('her', 7), ('best', 2), ('those', 4), ('lunar', 1), ('thou', 13), ('to', 20), ('shaken', 1), ('cause', 1), ('or', 2), ('mak', 1), ('eagle', 1), ('whither', 1), ('hearts', 1), ('erspread', 1), ('far', 1), ('shall', 1), ('parnassus', 1), ('had', 3), ('lamp', 1), ('largeliest', 1), ('bright', 1), ('happiest', 1), ('rds', 1), ('resplendence', 1), ('together', 1), ('primal', 1), ('comes', 3), ('ask', 1), ('void', 1), ('peer', 1), ('song', 1), ('thee', 1), ('make', 1), ('set', 2), ('ocean', 1), ('such', 6), ('need', 1), ('favour', 1), ('printed ...
# [('glaucus', 1),
#  ('allowed', 1),
#  ('memory', 1),
#  ('false', 1),
#  ('boiling', 1),
#  ('en', 1),
#  ('mortals', 1),
#  ('ran', 1),
#  ('sea', 1),
#  ('source', 1),
#  ('lighter', 1),
#  ('being', 1),
#  ('bosom', 1),
#  ('before', 1),
#  ('fast', 1),
#  ('bick', 1),
#  ('frenzied', 1),
#  ('sacred', 1),
#  ('enterprise', 1),
#  ('calm', 1),
#  ('pierian', 1),
#  ('sheds', 1),
#  ('marsyas', 1),
#  ('appear', 1),
#  ('higher', 1),
#  ('gods', 1),
#  ('accompanied', 1),
#  ('said', 1),
#  ('knits', 1),
#  ('stood', 1),
#  ('guide', 1),
#  ('suffic', 1),
#  ('up', 1),
#  ('child', 1),
#  ('behold', 1),
#  ('diver', 1),
#  ('steep', 1),
#  ('apollo', 1),
#  ('tree', 1),
#  ('voice', 1),
#  ('though', 1),
#  ('passage', 1),
#  ('line', 1),
#  ('bear', 1),
#  ('absorb', 1),
#  ('bard', 1),
#  ('dwelling', 1),
#  ('newly', 1),
#  ('dost', 1),
#  ('threefold', 1),
#  ('sky', 1),
#  ('vessel', 1),
#  ('resemble', 1),
#  ('transhuman', 1),
#  ('iron', 1),
#  ('herb', 1),
#  ('than', 1),
#  ('divine', 1),
#  ('piteous', 1),
#  ('ris', 1),
#  ('others', 1),
#  ('entangled', 1),
#  ('second', 1),
#  ('joy', 1),
#  ('morning', 1),
#  ('never', 1),
#  ('crown', 1),
#  ('lake', 1),
#  ('wheel', 1),
#  ('mighty', 1),
#  ('brief', 1),
#  ('reflected', 1),
#  ('do', 1),
#  ('four', 1),
#  ('delphic', 1),
#  ('glory', 1),
#  ('bodies', 1),
#  ('limbs', 1),
#  ('risen', 1),
#  ('drawn', 1),
#  ('mother', 1),
#  ('tasted', 1),
#  ('beheld', 1),
#  ('seest', 1),
#  ('bow', 1),
#  ('imagination', 1),
#  ('bedeck', 1),
#  ('impart', 1),
#  ('sparks', 1),
#  ('look', 1),
#  ('sigh', 1),
#  ('world', 1),
#  ('spark', 1),
#  ('off', 1),
#  ('rain', 1),
#  ('enter', 1),
#  ('shame', 1),
#  ('what', 1),
#  ('unmov', 1),
#  ('aspect', 1),
#  ('open', 1),
#  ('ever', 1),
#  ('inflam', 1),
#  ('must', 1),
#  ('might', 1),
#  ('prompts', 1),
#  ('wheels', 1),
#  ('partakes', 1),
#  ('ning', 1),
#  ('havens', 1),
#  ('gaze', 1),
#  ('rises', 1),
#  ('natures', 1),
#  ('seldom', 1),
#  ('gathers', 1),
#  ('straight', 1),
#  ('act', 1),
#  ('mind', 1),
#  ('trac', 1),
#  ('beam', 1),
#  ('dull', 1),
#  ('caesar', 1),
#  ('near', 1),
#  ('other', 1),
#  ('theme', 1),
#  ('example', 1),
#  ('circles', 1),
#  ('pierces', 1),
#  ('thyself', 1),
#  ('cannot', 1),
#  ('leaves', 1),
#  ('depth', 1),
#  ('benign', 1),
#  ('gain', 1),
#  ('r', 1),
#  ('clearly', 1),
#  ('create', 1),
#  ('blaze', 1),
#  ('constellation', 1),
#  ('spirit', 1),
#  ('serve', 1),
#  ('joins', 1),
#  ('beyond', 1),
#  ('keener', 1),
#  ('pray', 1),
#  ('satisfied', 1),
#  ('therefore', 1),
#  ('admire', 1),
#  ('seen', 1),
#  ('henceforth', 1),
#  ('rest', 1),
#  ('elsewhere', 1),
#  ('utt', 1),
#  ('blackness', 1),
#  ('seem', 1),
#  ('fit', 1),
#  ('claims', 1),
#  ('whose', 1),
#  ('sphere', 1),
#  ('high', 1),
#  ('perchance', 1),
#  ('foot', 1),
#  ('honour', 1),
#  ('themselves', 1),
#  ('small', 1),
#  ('lunar', 1),
#  ('shaken', 1),
#  ('cause', 1),
#  ('mak', 1),
#  ('eagle', 1),
#  ('whither', 1),
#  ('hearts', 1),
#  ('erspread', 1),
#  ('far', 1),
#  ('shall', 1),
#  ('parnassus', 1),
#  ('lamp', 1),
#  ('largeliest', 1),
#  ('bright', 1),
#  ('happiest', 1),
#  ('rds', 1),
#  ('resplendence', 1),
#  ('together', 1),
#  ('primal', 1),
#  ('ask', 1),
#  ('void', 1),
#  ('peer', 1),
#  ('song', 1),
#  ('thee', 1),
#  ('make', 1),
#  ('ocean', 1),
#  ('need', 1),
#  ('favour', 1),
#  ('printed', 1),
#  ('remov', 1),
#  ('lips', 1),
#  ('thirst', 1),
#  ('instinct', 1),
#  ('rais', 1),
#  ('thing', 1),
#  ('proper', 1),
#  ('belov', 1),
#  ('worldly', 1),
#  ('wreath', 1),
#  ('ear', 1),
#  ('pow', 1),
#  ('been', 1),
#  ('smiles', 1),
#  ('be', 1),
#  ('both', 1),
#  ('deprav', 1),
#  ('gazing', 1),
#  ('harmony', 1),
#  ('gives', 1),
#  ('suffer', 1),
#  ('hast', 1),
#  ('became', 1),
#  ('gracious', 1),
#  ('hand', 1),
#  ('already', 1),
#  ('love', 1),
#  ('animals', 1),
#  ('hither', 1),
#  ('how', 1),
#  ('end', 1),
#  ('passages', 1),
#  ('let', 1),
#  ('flood', 1),
#  ('relate', 1),
#  ('see', 1),
#  ('aim', 1),
#  ('could', 1),
#  ('answer', 1),
#  ('sire', 1),
#  ('charm', 1),
#  ('shine', 1),
#  ('admiration', 1),
#  ('remaining', 1),
#  ('again', 1),
#  ('sound', 1),
#  ('diversely', 1),
#  ('city', 1),
#  ('rance', 1),
#  ('witness', 1),
#  ('come', 1),
#  ('happy', 1),
#  ('scap', 1),
#  ('bears', 1),
#  ('deep', 1),
#  ('makes', 1),
#  ('laurel', 1),
#  ('cirrhaean', 1),
#  ('eve', 1),
#  ('shadow', 1),
#  ('newness', 1),
#  ('last', 1),
#  ('left', 1),
#  ('eyesight', 1),
#  ('wills', 1),
#  ('even', 1),
#  ('brows', 1),
#  ('pass', 1),
#  ('divested', 1),
#  ('foliage', 1),
#  ('dragg', 1),
#  ('lean', 1),
#  ('impression', 1),
#  ('steps', 1),
#  ('brute', 1),
#  ('hemisphere', 1),
#  ('thanks', 1),
#  ('hadst', 1),
#  ('cross', 1),
#  ('another', 1),
#  ('pilgrim', 1),
#  ('upwards', 1),
#  ('whiteness', 1),
#  ('will', 1),
#  ('turn', 1),
#  ('exceeds', 1),
#  ('tell', 1),
#  ('casts', 1),
#  ('nathless', 1),
#  ('surpasseth', 1),
#  ('rul', 1),
#  ('whenas', 1),
#  ('around', 1),
#  ('nor', 1),
#  ('proof', 1),
#  ('felt', 1),
#  ('were', 1),
#  ('triumph', 1),
#  ('follow', 1),
#  ('vast', 1),
#  ('desired', 1),
#  ('weak', 1),
#  ('binds', 1),
#  ('almost', 1),
#  ('above', 1),
#  ('spring', 1),
#  ('tow', 1),
#  ('measur', 1),
#  ('us', 1),
#  ('art', 1),
#  ('believ', 1),
#  ('inspir', 1),
#  ('unsheath', 1),
#  ('matter', 1),
#  ('fancy', 1),
#  ('change', 1),
#  ('hence', 1),
#  ('issue', 1),
#  ('shalt', 1),
#  ('ring', 1),
#  ('suddenly', 1),
#  ('different', 1),
#  ('breast', 1),
#  ('view', 1),
#  ('upward', 1),
#  ('breathe', 1),
#  ('each', 1),
#  ('directs', 1),
#  ('although', 1),
#  ('wax', 1),
#  ('aid', 1),
#  ('inwardly', 1),
#  ('giv', 1),
#  ('they', 1),
#  ('troubled', 1),
#  ('labour', 1),
#  ('broad', 1),
#  ('canto', 1),
#  ('o', 2),
#  ('at', 2),
#  ('words', 2),
#  ('him', 2),
#  ('eternal', 2),
#  ('here', 2),
#  ('less', 2),
#  ('own', 2),
#  ('forth', 2),
#  ('ne', 2),
#  ('course', 2),
#  ('into', 2),
#  ('began', 2),
#  ('universe', 2),
#  ('among', 2),
#  ('store', 2),
#  ('doubt', 2),
#  ('mov', 2),
#  ('realm', 2),
#  ('didst', 2),
#  ('desire', 2),
#  ('ken', 2),
#  ('better', 2),
#  ('only', 2),
#  ('whence', 2),
#  ('some', 2),
#  ('grace', 2),
#  ('return', 2),
#  ('approaching', 2),
#  ('earth', 2),
#  ('saw', 2),
#  ('day', 2),
#  ('flame', 2),
#  ('god', 2),
#  ('place', 2),
#  ('have', 2),
#  ('temper', 2),
#  ('myself', 2),
#  ('first', 2),
#  ('worth', 2),
#  ('new', 2),
#  ('mortal', 2),
#  ('intellect', 2),
#  ('best', 2),
#  ('or', 2),
#  ('set', 2),
#  ('thoughts', 2),
#  ('s', 2),
#  ('long', 2),
#  ('yet', 2),
#  ('part', 2),
#  ('beatrice', 2),
#  ('bent', 2),
#  ('whom', 2),
#  ('wont', 2),
#  ('e', 2),
#  ('order', 2),
#  ('creatures', 2),
#  ('she', 2),
#  ('kind', 2),
#  ('know', 2),
#  ('human', 2),
#  ('after', 2),
#  ('rise', 2),
#  ('great', 2),
#  ('fire', 2),
#  ('thence', 2),
#  ('much', 3),
#  ('upon', 3),
#  ('form', 3),
#  ('st', 3),
#  ('if', 3),
#  ('their', 3),
#  ('now', 3),
#  ('may', 3),
#  ('er', 3),
#  ('eyes', 3),
#  ('heav', 3),
#  ('are', 3),
#  ('had', 3),
#  ('comes', 3),
#  ('power', 3),
#  ('things', 3),
#  ('mine', 3),
#  ('then', 3),
#  ('he', 3),
#  ('it', 3),
#  ('our', 3),
#  ('hath', 4),
#  ('more', 4),
#  ('who', 4),
#  ('when', 4),
#  ('but', 4),
#  ('made', 4),
#  ('there', 4),
#  ('light', 4),
#  ('through', 4),
#  ('sun', 4),
#  ('those', 4),
#  ('not', 4),
#  ('fix', 4),
#  ('thus', 4),
#  ('all', 4),
#  ('one', 4),
#  ('n', 5),
#  ('thy', 5),
#  ('its', 5),
#  ('his', 6),
#  ('on', 6),
#  ('such', 6),
#  ('was', 6),
#  ('which', 6),
#  ('this', 7),
#  ('by', 7),
#  ('her', 7),
#  ('for', 7),
#  ('is', 8),
#  ('so', 8),
#  ('my', 9),
#  ('a', 10),
#  ('in', 11),
#  ('from', 11),
#  ('as', 12),
#  ('me', 12),
#  ('thou', 13),
#  ('with', 13),
#  ('i', 14),
#  ('to', 20),
#  ('that', 23),
#  ('and', 24),
#  ('of', 25),
#  ('d', 36),
#  ('the', 44)]

# %%
del list
