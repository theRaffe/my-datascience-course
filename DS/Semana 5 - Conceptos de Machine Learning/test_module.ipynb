# %%
# %matplotlib inline
import pandas as pd
from datascience_module.descriptive_statistics.regression_model import RegressionModel

# %%
USAhousing = pd.read_csv("../Semana 4 - Estadística para la exploración y análisis de datos/USA_Housing.csv")
USAhousing.columns = ['Income', 'Age', 'No_rooms' , 'No_bedrooms' , 'Population' , 'Price' , 'Address']

# %%
x_features = ['Income', 'Age', 'No_rooms' , 'No_bedrooms' , 'Population']
y_target = 'Price'
regression_m = RegressionModel(USAhousing,x_features, y_target)
regression_m.execute_regression()
