# %% [markdown]
# # Solución al Scrapeo de Mercado Libre
# El primer paso es importar las 3 librerias fundamentales para el scrapeo con beautifulsoup.

# %%
from bs4 import BeautifulSoup
import pandas as pd
import requests

# %% [markdown]
# En este caso; decidí hacer una prueba con el departamento de celulares de mercadolibre. Este código que sigue se va a contruir de poco en poco para ver que podamos importar los datos que queremos de cada página y ver si somos capaces de encontrar enlaces que nos lleven a las siguientes páginas donde podemos encontrar más productos.

# %%
URL1 = 'https://celulares.mercadolibre.com.mx'
URL1 = BeautifulSoup(requests.get(URL1).text, "lxml")

# %% [markdown]
# A continuación encontramos los tags de Names (Nombre de producto), Price (Precio actual del producto), Nextpage (enlaces a las siguientes páginas de la sección de celulares) y Sale (Número de productos vendidos.
#
# La parte de discount se utiliza por que no en todos los productos hay un descuento; en ese caso el número de descuentos sería menor al número de precios lo cual no nos ayuda mucho en el la realización de la base de datos. Lo que se hace es invetigar cada producto uno por uno y ver si hay una sección de price-old que indica descuento. Si existe; entonces sustituimos el precio en la lista descuentos pero si no entonces especificamos que no hay descuento.
#
# El siguiente código solo analiza la primera página de mercadolibre.

# %%
Name = [row.get_text() 
        for row in URL1.find_all('span',class_='main-title')]

Price = [row.get_text() 
         for row in URL1.find_all('span',class_='price__fraction')]

Nextpage = [row['href'] 
            for row in URL1.find_all('a',class_='andes-pagination__link', href=True)]

Sale = [row.get_text() 
        for row in URL1.find_all('div',class_='item__condition')]
#Solución no elegante, pero funcional

Discount=[]

for item in URL1.find_all('li',class_='results-item'):
    x = item.find_all('span',class_='price-old')
    if x == []:
        Discount.append('No Discount')
    else:
        Discount.append(x[0].get_text())
'''Al obtener los enlaces notamos que los primeros 2 no nos
sirven ya que nos hacen regresar o nos hacen quedarnos en donde estamos.'''
# El último corresponde a la flecha de adelante.
del Nextpage[0]
del Nextpage[0]
del Nextpage[-1]
print(len(Price), len(Discount))
# Out:
# 53 53

# %% [markdown]
# Una vez hecho eso; hacemos un for en donde se hace todo lo anterior; comenzamos con un request y luego extraemos la información de esa página por lo cual estámos navegando una lista de direcciones web y extrayendo la información de cada una!

# %%
for URL in Nextpage:
    Scrap = BeautifulSoup(requests.get(URL).text, "lxml")
    
    Names = [row.get_text() 
             for row in Scrap.find_all('span', class_ = 'main-title')]
    
    Prices = [row.get_text() 
              for row in Scrap.find_all('span', class_ = 'price__fraction')]
    
    Sales = [row.get_text() f
             or row in Scrap.find_all('div', class_ = 'item__condition')]
    
    Discounts = []
    
    for item in Scrap.find_all('li', class_='results-item'):
        
        x = item.find_all('span', 
                          class_='price-old')
        
        if x == []:
            
            Discounts.append('No Discount')
            
        else:
            
            Discounts.append(x[0].get_text())
            
    Name = Name + Names
    Price = Price + Prices
    Discount = Discount + Discounts
    Sale = Sale + Sales

# %% [markdown]
# Después podemos hacer la limpieza de los datos; eliminamos texto no deseado, podemos pasar de strings a números para poder hacer operaciones sobre ellos más facilmente y finalmente terminamos por crear un dataframe con los parámetros deseados.

# %%
#Limpieza, símbolos y transformación.
Price = [p.replace(',','') for p in Price]
Price = [int(p) for p in Price]
Dollar = list(map(lambda x: x/20,Price))

# %%
df=pd.DataFrame({'Name': Name, 'Price': Price, 'Discount': Discount, 'Sales': Sale, 'Dollar': Dollar})
df.to_csv('Mercado.csv')
df
# Out:
#                                                  Name  Price     Discount  \
# 0    Xiaomi Mi A2 Lite 64+4gb Global 12+5+5mpx Nuevo    3870  No Discount
# 1    Celular Moto E4 16gb Ram 2gb Quad Core Androi...   1749    $ 1,999
# 2    Celular Samsung Galaxy M20 32gb Ram 3gb Super...   3588    $ 3,987
# 3    Celular Samsung Galaxy M10 16gb Ram 2gb Nuevo...   2567    $ 2,853
# 4    Huawei Y9 2019 64gb Dual Sim 3gb Ram Camara D...   4849  No Discount
# 5            Celular Apple iPhone 6 16gb 4g Lte Demo    3399    $ 4,999
# 6    Celular Samsung Galaxy M30 64gb 4gb R 3 Camar...   5199    $ 5,777
# 7       Huawei P30 128gb + 6gb Ram + Regalo Watch Gt   15949  No Discount
# 8     Celular Motorola Moto E5 Play 16gb Ram 2gb 5.2    1998    $ 2,220
# 9    Celular Lg V20 64gb 16mp Android 7 Liberado D...   2925    $ 3,999
# 10          Celular Lg Phoenix 3 16gb Negro Liberado    1299  No Discount
# 11   Samsung Galaxy S10+ Plus 128gb+8ram Exynos Nu...  19670  No Discount
# 12   Celular Huawei Honor 8x 64gb 4gb Ram Dual Sim...   5299  No Discount
# 13   Celular Samsung Galaxy M20 32gb Ram 3gb Super...   3588    $ 3,987
# 14   Motorola Moto G6 Play 16gb Lector De Huella +...   3399  No Discount
# 15   Celular Motorola Moto G7 Power 4gb 64gb Desbl...   4999    $ 5,599
# 16   Motorola Moto One 64gb+4ram Dualsim Nuevo Cam...   4620  No Discount
# 17   Celular Samsung Galaxy M30 64gb 4gb R 3 Camar...   5199    $ 5,777
# 18   Huawei P Smart 2019 32gb Dual Sim 3gb Ram Dob...   4499  No Discount
# 19   Celular Xiaomi Redmi Note 7 64gb 4gb Ram 4g L...   4599    $ 5,399
# 20   Huawei P20 Lite 32gb Dual Sim Nuevo Original ...   4879  No Discount
# 21   Celular Motorola Moto E4 16gb 2gb Ram 4g Lte ...   1899  No Discount
# 22   Celular Xiaomi Mi 8 Lite 64gb + 4gb 24mpx Dua...   4799  No Discount
# 23   Huawei Mate 20 Lite Dual Sim 64gb 4gb Ram Nue...   5888  No Discount
# 24   Samsung Galaxy A7 2018 6pg 64gb+4ram 24+8+5mp...   5870  No Discount
# 25   Huawei Y9 2019 Dual Sim 4g Lte 64gb 4 Cámaras...   4849  No Discount
# 26    Celular Motorola Moto G6 Play 4g Lte 16gb 2ram    2799    $ 3,599
# 27   Celular Xiaomi Redmi Note 6 Pro 64gb 4ram 4g ...   4497    $ 5,999
# 28   Honor 8x 64gb+4ram Dualsim Nuevo 4g Android 8...   4940  No Discount
# 29                Motorola Moto E5 Plus 32gb 3gb Ram    3499  No Discount
# 30   Huawei Nova 4 Dual Sim 128gb 8gb Ram Triple C...  10799  No Discount
# 31   Celular Motorola Moto E5 Plus 2gb 16gb Desblo...   2999    $ 4,299
# 32   Celular Apple iPhone 6s 64gb + Funda Silicon ...   5699  No Discount
# 33   Samsung Galaxy Note 9 6.4p 128+6ram 12.2+12+8...  14845  No Discount
# 34   Celular Samsung Galaxy M10 16gb Ram 2gb Nuevo...   2567    $ 2,853
# 35   Celular Huawei P20 Lite 4g Lte 32gb 4gb Ram 1...   5299  No Discount
# 36   Celular Xiaomi Mi 8 Lite 64gb 4gb Ram Dual Si...   5699    $ 6,599
# 37   Motorola G6 Play, 4g Lte 5.7 13mp Lector De H...   2999    $ 3,999
# 38   Xiaomi Redmi 6 32gb+3ram Global Lte 5.4p Cáma...   2720  No Discount
# 39     Celular Motorola Moto E4 16gb 4g Lte Liberado    1664    $ 1,899
# 40   Xiaomi Mi A2 Lite 64+4gb Global 12+5+5mpx Meses    3899  No Discount
# 41   Celular Xiaomi Mi 8 Lite 128gb 6gb Ram Dual S...   6548    $ 6,999
# 42   Xiaomi Redmi Note 6 Pro 64gb Dual Sim 4gb Ram...   4399  No Discount
# 43   Xiaomi Redmi Note 6 Pro 64gb+4ram Nuevo Globa...   4289  No Discount
# 44   Celular Motorola Moto One 4gb 64gb Desbloquea...   4999    $ 7,999
# 45                Celular Apple iPhone 6 64gb 4g Lte    4699    $ 5,899
# 46   Moto Z3 Play Xt1929-6 64gb 4gb Ram Libre Sell...   6989  No Discount
# 47   Celular Motorola Moto G5s Plus 32gb + 3gb Ram...   3514    $ 3,699
# 48   Xiaomi Mi 8 Lite 64gb+ 4 Ram Versión Global N...   4499  No Discount
# 49   Samsung Galaxy Note 9 6.4p 128+6ram 12.2+12+8...  14750  No Discount
# 50   Xiaomi Mi A2 Global Dual 64+4ram 12+20mpx And...   3970  No Discount
# 51   Xiaomi Mi 8 Lite 64gb 4gb Ram Dual Sim Versio...   4649  No Discount
# 52   Xiaomi Redmi Note 6 Pro 64gb+4ram Nuevo Globa...   4370  No Discount
#
#                          Sales  Dollar
# 0               1836 vendidos   193.50
# 1                757 vendidos    87.45
# 2               3662 vendidos   179.40
# 3                964 vendidos   128.35
# 4                353 vendidos   242.45
# 5                866 vendidos   169.95
# 6               2354 vendidos   259.95
# 7                138 vendidos   797.45
# 8                325 vendidos    99.90
# 9                920 vendidos   146.25
# 10               256 vendidos    64.95
# 11                98 vendidos   983.50
# 12               305 vendidos   264.95
# 13              3662 vendidos   179.40
# 14               653 vendidos   169.95
# 15               208 vendidos   249.95
# 16               217 vendidos   231.00
# 17              2354 vendidos   259.95
# 18               218 vendidos   224.95
# 19     858 vendidos - Hidalgo   229.95
# 20               591 vendidos   243.95
# 21               567 vendidos    94.95
# 22               235 vendidos   239.95
# 23               439 vendidos   294.40
# 24               653 vendidos   293.50
# 25               416 vendidos   242.45
# 26               281 vendidos   139.95
# 27               992 vendidos   224.85
# 28               178 vendidos   247.00
# 29               201 vendidos   174.95
# 30                65 vendidos   539.95
# 31               181 vendidos   149.95
# 32   626 vendidos - Chihuahua   284.95
# 33               124 vendidos   742.25
# 34               964 vendidos   128.35
# 35              1845 vendidos   264.95
# 36               709 vendidos   284.95
# 37               325 vendidos   149.95
# 38               758 vendidos   136.00
# 39              1468 vendidos    83.20
# 40               488 vendidos   194.95
# 41               275 vendidos   327.40
# 42               348 vendidos   219.95
# 43               707 vendidos   214.45
# 44               135 vendidos   249.95
# 45               423 vendidos   234.95
# 46               657 vendidos   349.45
# 47               574 vendidos   175.70
# 48               499 vendidos   224.95
# 49               210 vendidos   737.50
# 50               776 vendidos   198.50
# 51               310 vendidos   232.45
# 52               227 vendidos   218.50

# %% [markdown]
# # Ejercicio palacio de hierro
# Comenzamos por hacer un request por la página del departamento de bolsos de palacio de hierro.

# %%
URL2 = 'https://www.elpalaciodehierro.com/lujo/mujer/accesorios/bolsos.html'
URL2 = BeautifulSoup(requests.get(URL2).text, "lxml")

# %% [markdown]
# Ahora vamos a extraer la información relevante del documento html por medio de una comprensión de lista; inclusive se hace el filtrado de la variable precio ya que cuenta con un caracter adicional que no es de nuestro interés y puede terminar complicando el análisis de los datos.
#
# La variable next page palacio cuenta con los enlaces de las siguientes páginas del catálogo de bolsas Palacio.

# %%
MarcaPalacio = [row.get_text().strip() 
                for row in URL2.find_all('p', class_ = 'ls-grid-title')]

NamePalacio = [row['title'] 
               for row in URL2.find_all('span', title = True)]

PricePalacio = [row.get_text().strip() 
                for row in URL2.find_all('span', class_ = 'price')]

PricePalaciofilt = [word.replace(u'\xa0', '') 
                    for word in PricePalacio]

NextpagePalacio = ['https://www.elpalaciodehierro.com' + link['href'] 
                   for link in URL2.find_all('a', class_ = 'nume', href = True)]

NextpagePalacio = NextpagePalacio[0:3]

print(NextpagePalacio)
# Out:
# ['https://www.elpalaciodehierro.com/lujo/mujer/accesorios/bolsos.html?p=2', 'https://www.elpalaciodehierro.com/lujo/mujer/accesorios/bolsos.html?p=3', 'https://www.elpalaciodehierro.com/lujo/mujer/accesorios/bolsos.html?p=4']

# %% [markdown]
# Con esto podemos hacer un ciclo for para scrappear esas páginas y juntar los resultados en una gran lista individual.

# %%
for link in NextpagePalacio:
    URL = BeautifulSoup(requests.get(link).text, "lxml")
    
    MarcaPalacios = [row.get_text().strip() 
                     for row in URL2.find_all('p', class_ = 'ls-grid-title')]
    
    NamePalacios = [row['title'] 
                    for row in URL.find_all('span', title = True)]
    
    PricePalacios = [row.get_text().strip() 
                     for row in URL.find_all('span', class_ = 'price')]
    
    PricePalaciosfilt = [word.replace(u'\xa0', '') 
                         for word in PricePalacios]
    
    NamePalacio = NamePalacio + NamePalacios
    PricePalaciofilt = PricePalaciofilt + PricePalaciosfilt
    MarcaPalacio = MarcaPalacio + MarcaPalacios
# Out:
# ['Cosmetiquera', 'Bolso de mano Gancini', 'Bolso mini con lazo Vara', 'Bolso crossbody en piel', 'Bolso satchel en piel', 'Bolso pequeño', 'Bolso satchel en piel', 'Bolso lazo Vara con solapa frontal', 'Ferragamo Studio bag', 'Bolso de Mano Gancini', 'Bolso de Mano Gancini', 'Bolso crossbody animal skin', 'Bolso Sofia', 'Tote Ferragamo Studio bag', 'Bolso compacto Gancini', 'Bolso Gancini con solapa frontal', 'Bolso mini lazo Vara', 'Bolso shopper con grafiti de piel', 'Bolso crossbody de piel con animal print', 'Bolso crossbody de piel', 'Bolso shoulder de piel', 'Bolso tote de piel con animal print', 'Bolso tote de piel', 'Bolso backpack de piel', 'Bolso satchel de piel', 'Bolso tote en piel', 'Bolso Whip Piel', 'Bolso Cangurera Piel', 'Bolso crossbody de piel granulada', 'Bolso Whip Piel', 'Bolso Whip Piel', 'Bolso satchel de piel', 'Bolso Gem Piel Capitonado', 'Bolso Pouch algodón Flores', 'Bolso Bucket Piel', 'Bolso crossbody de piel granulada', 'Bolso Bucket Piel', 'Bolso Whip Piel', 'Cangurera Piel', 'Bolso Piel', 'Bolso crossbody en piel', 'Bolso tote en piel', 'Bolso satchel en piel en monogram', 'Bolso sobre en piel', 'Bolso satchel de piel', 'Bolso backpack monogram', 'Bolso tote en piel', 'Bolso satchel en piel', 'Bolso satchel en piel', 'Bolso satchel en piel', 'Bolso crossbody en piel', 'Bolso tote en piel', 'Bolso crossbody en piel', 'Bolso tote en piel', 'Bolso Crossbody en piel', 'Bolso crossbody en piel', 'Bolso tote en piel', 'Bolso tote en piel', 'Bolso backpack en piel', 'Bolso backpack en piel', 'Bolso backpack en piel', 'Bolso crossbody en piel', 'Bolso crossbody en piel', 'Bolso satchel en piel', 'Bolso crossbody en piel', 'Bolso satchel en piel', 'Bolso crossbody en piel', 'Bolso tote en piel con hojas', 'Bolso backpack en piel', 'Bolso crossbody en piel', 'Bolso crossbody en piel', 'Bolso crossbody en piel', 'Bolso crossbody en piel', 'Bolso crossbody en piel floral', 'Bolso crossbody en piel', 'Bolso tote en piel', 'Bolso crossbody en piel', 'Bolso crossbody de piel', 'Bolso crossbody de piel', 'Bolso crossbody', 'Bolso crossbody de piel', 'Bolso crossbody de piel granulada', 'Bolso crossbody en piel', 'Bolso clutch de piel', 'Bolso crossbody en piel con rombos', 'Bolso crossbody', 'Bolso Tote', 'Bolso shoulder de piel', 'Bolso wristlet Mujer', 'Bolso crossbody en piel con rombos', 'Bolso satchel de piel', 'Bolso satchel de piel', 'Bolso satchel en piel', 'Bolso tote capitonado', 'Bolso crossbody en piel', 'Bolso crossbody en piel con rombos', 'Bolso crossbody', 'Bolso Tote', 'Bolso crossbody en piel', 'Bolso tote de piel', 'Bolso crossbody', 'Bolso crossbody en piel', 'Bolso crossbody en piel', 'Bolso satchel en piel', 'Bolso crossbody en piel', 'Bolso satchel en piel', 'Bolso crossbody de piel', 'Bolso Butterfly Piel', 'Bolso crossbody de piel', 'Bolso satchel en piel', 'Bolso satchel en piel', 'Bolso clutch Mujer', 'Bolso tote de piel', 'Bolso satchel en piel', 'Bolso crossbody en piel', 'Bolso crossbody de piel', 'Bolso crossbody en piel', 'Bolso shoulder', 'Bolso shoulder de piel', 'Bolso satchel de piel', 'Bolso crossbody en piel', 'Bolso satchel de piel con animal print', 'Bolso crossbody en piel con rombos', 'Bolso crossbody en piel con rombos', 'Bolso crossbody en piel', 'Bolso tote en piel', 'Bolso crossbody de piel', 'Bolso shoulder de piel', 'Bolso crossbody', 'Bolso crossbody Piel', 'Bolso bucket', 'Bolso crossbody', 'Bolso satchel con franjas de piel', 'Bolso crossbody en piel', 'Bolso crossbody', 'Bolso satchel de piel en charol', 'Bolso crossbody', 'Bolso crossbody de piel con charol', 'Bolso crossbody', 'Bolso clutch de piel', 'Bolso tote en piel', 'Mini bolsa con cierre de clip', 'Bolso clutch con estrellas', 'Bolso mini con lazo Vara', 'Bolso Gancini con solapa', 'Bolso Gancini grande con solapa', 'Bolso Gancini grande con solapa', 'Bolso backpack', 'Bolso con solapa Gancini', 'Bolso Tote Gancini', 'Bolso de pulsera Gancini', 'Bolsa Gancini grande con solapa', 'Bolso lazo Vara con  ...

# %% [markdown]
# Para terminar; solo metemos las listas en un diccionario y terminamos exportandola en un csv que podemos encontrar en la misma carpeta que este documento.

# %%
df=pd.DataFrame({'Marca':MarcaPalacio,'Nombre':NamePalacio,'Precio':PricePalacioc})
df.to_csv('Palacio.csv')

# %% [markdown]
# # Scraping de Soriana
# La última página por scrapear es Soriana; nuevamente escogemos un departamento de nuestro interés que puede ser el de pantallas de Soriana por decir. Pueden usar cualquier otro que gusten ya que la estructura es la misma. Comenzamos por usar la misma instrucción

# %%
URL2 = 'https://www.soriana.com/soriana/es/c/Electronica/Pantallas/Pantallas/c/111'
URL2 = BeautifulSoup(requests.get(URL2).text, "lxml")

# %%
NomSoriana = [Nom.get_text().strip() 
              for Nom in URL2.find_all('a',class_="name")]

PrecioSoriana = [precio.get_text().strip() 
                 for precio in URL2.find_all('span',class_='price')]

DiscountSoriana = []

for item in URL2.find_all('div',class_='priceContainer'):
    x = item.find('span',class_='sale-original-price')
    if x == None:
        DiscountSoriana.append('Igual')
    else:
        DiscountSoriana.append(x.get_text())
        
for links in URL2.find_all('ul',class_='pagination'):
    enlaces = ['https://www.soriana.com'+link['href'] for link in links.find_all('a',class_='',href=True)]
    
print(enlaces)
# Out:
# ['https://www.soriana.com/soriana/es/c/Electr%C3%B3nica/Pantallas/Pantallas/c/111?q=%3Arelevance&page=1', 'https://www.soriana.com/soriana/es/c/Electr%C3%B3nica/Pantallas/Pantallas/c/111?q=%3Arelevance&page=2']

# %%
for enlace in enlaces:
    
    Scrap = BeautifulSoup(requests.get(enlace).text, "lxml")
    
    NomSorianas = [Nom.get_text().strip() 
                   for Nom in Scrap.find_all('a',class_="name")]
    PrecioSorianas = [precio.get_text().strip() 
                      for precio in Scrap.find_all('span',class_='price')]
    
    DiscountsSoriana=[]
    
    for item in Scrap.find_all('div', class_='priceContainer'):
        x = item.find('span', class_='sale-original-price')
        if x == None:
            DiscountsSoriana.append('No Discount')
        else:
            DiscountsSoriana.append(x.get_text())
    
    DiscountSoriana = DiscountSoriana + DiscountsSoriana
    
    NomSoriana = NomSoriana + NomSorianas
    
    PrecioSoriana = PrecioSoriana + PrecioSorianas
# Out:
# ['$15,999.00', '$11,999.00', '$29,999.00', '$19,999.00', '$26,999.00', '$3,899.00', '$49,999.00', '$34,999.00', '$6,999.00', '$24,999.00', '$5,999.00', '$5,499.00', '$88,999.00', '$16,499.00', '$11,889.00', '$10,999.00', '$13,799.00', '$18,499.00', '$18,399.00', '$15,499.00', '$19,999.00', '$13,999.00', '$18,999.00', 'Igual', '$15,999.00', '$15,999.00', '$11,799.00', '$13,499.00', '$13,999.00', '$9,999.00', '$8,199.00', '$23,999.00', '$15,699.00', '$16,999.00', '$25,999.00', '$35,999.00', '$11,679.00', '$7,899.00', '$6,790.00', '$17,999.00', '$6,999.00', '$5,299.00', '$19,999.00', '$14,999.00', '$46,999.00', '$4,499.00', '$3,149.00', 'Igual', 'Igual', '$4,999.00', '$7,999.00', '$27,799.00', '$25,999.00', '$6,999.00']

# %%
DatosSor=pd.DataFrame({'Product':NomSoriana, 'Precio Original':DiscountSoriana, 'Precio Descontado':PrecioSoriana})
